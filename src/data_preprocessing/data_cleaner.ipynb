# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
os.chdir(r'C:\Users\DELL\Desktop\collage\projects\CyberBERT\cyberbert_project')

# %%
df1=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
df2=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
df3=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv')
df4=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv')
df5=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
df6=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
df7=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv')
df8=pd.read_csv('data/raw/MachineLearningCSV/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')

# %%
df=pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True)
df.head(5)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# ...

# %%
# Convert only int columns to float
int_cols = df.select_dtypes(include=['int64']).columns
df[int_cols] = df[int_cols].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830743 entries, 0 to 2830742
# Data columns (total 79 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0    Destination Port             float64
#  1    Flow Duration                float64
#  2    Total Fwd Packets            float64
#  3    Total Backward Packets       float64
#  4   Total Length of Fwd Packets   float64
#  5    Total Length of Bwd Packets  float64
#  6    Fwd Packet Length Max        float64
#  7    Fwd Packet Length Min        float64
#  8    Fwd Packet Length Mean       float64
#  9    Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max         float64
#  11   Bwd Packet Length Min        float64
#  12   Bwd Packet Length Mean       float64
#  13   Bwd Packet Length Std        float64
#  14  Flow Bytes/s                  float64
#  15   Flow Packets/s               float64
#  16   Flow IAT Mean                float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(308381)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.shape)
df.head()
# Out:
# (2522362, 79)
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0            54865.0             3.0                 2.0
# 1            55054.0           109.0                 1.0
# 2            55055.0            52.0                 1.0
# 3            46236.0            34.0                 1.0
# 4            54863.0             3.0                 2.0
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                      0.0                         12.0
# 1                      1.0                          6.0
# 2                      1.0                          6.0
# 3                      1.0                          6.0
# 4                      0.0                         12.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           0.0                     6.0
# 1                           6.0                     6.0
# 2                           6.0                     6.0
# ...

# %%
df.to_csv('data/processed/clean_data.csv', index=False)

# %%
df2=pd.read_csv('data/processed/clean_data_02.csv')
df2.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0              53.0        71569.0                1.0                     1.0
# 1             443.0    115248755.0               44.0                    64.0
# 2            2719.0          118.0                1.0                     2.0
# 3              53.0          496.0                1.0                     1.0
# 4             443.0    117366780.0               20.0                    20.0
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                         44.0                        148.0
# 1                        884.0                      71908.0
# 2                          6.0                         12.0
# 3                         63.0                        123.0
# 4                       2750.0                       7235.0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# ...

# %%
df2['Label'].unique()
# Out:
# array(['BENIGN', 'DDoS', 'PortScan', 'FTP-Patator', 'SSH-Patator',
#        'DoS Slowhttptest', 'DoS GoldenEye'], dtype=object)

# %%
df2=df1.loc[(df1['Label'] == 'BENIGN') |  (df1['Label'] == 'PortScan') | (df1['Label'] == 'DDoS') | (df1['Label'] == 'FTP-Patator') | (df1['Label'] == 'SSH-Patator') | (df1['Label'] == 'DoS Slowloris') | (df1['Label'] == 'DoS Slowhttptest') | (df1['Label'] == 'DoS GoldenEye') ]

# %%
df2['Label'].unique()
# Out:
# array(['BENIGN', 'DDoS', 'PortScan', 'FTP-Patator', 'SSH-Patator',
#        'DoS Slowhttptest', 'DoS GoldenEye'], dtype=object)

# %%
# Sample only a fraction of BENIGN samples (e.g., 20%)
benign_df = df2[df2['Label'] == 'BENIGN'].sample(frac=0.025, random_state=42)
ddos_df = df2[df2['Label'] == 'DDos'].sample(frac=0.5, random_state=42)
portscan_df = df2[df2['Label'] == 'PortScan'].sample(frac=0.1, random_state=42)
ftp_df = df2[df2['Label'] == 'FTP-Patator'].sample(frac=0.5, random_state=42)
ssh_df = df2[df2['Label'] == 'SSH-Patator'].sample(frac=0.5, random_state=42)
doss_df = df2[df2['Label'] == 'DoS Slowhttptest'].sample(frac=0.5, random_state=42)
dosg_df = df2[df2['Label'] == 'DoS GoldenEye'].sample(frac=0.5, random_state=42)



df3 = pd.concat([benign_df,ddos_df,portscan_df,ftp_df,ssh_df,doss_df,dosg_df]).reset_index(drop=True)

# %%
df3.shape
# Out:
# (31897, 79)

# %%
df3.to_csv('data/processed/clean_data.csv', index=False)

# %%
df1.columns = df1.columns.str.strip()

# %%
df1.shape
# Out:
# (2522362, 79)

# %%
df1.to_csv('data/processed/clean_data1.csv', index=False)
